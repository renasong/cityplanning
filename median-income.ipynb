# %%
import glob
import pandas as pd
import geopandas 
import shapely.wkt
from shapely.geometry import Point, Polygon
import re

# %%
path = '/Users/renasong/Documents/2020su/proj/income'
all_files = glob.glob(path + "/*.csv")
li = []

for filename in all_files:
    df = pd.read_csv(filename)
    li.append(df)

raw = pd.concat(li, axis=0, ignore_index=True)
# Out:
# /Users/renasong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':

# %%
dfs=[pd.DataFrame(x) for x in li]

# %%
y2013=dfs[0]
y2016=dfs[1]
y2014=dfs[2]
y2011=dfs[3]
y2010=dfs[4]
y2015=dfs[5]
y2018=dfs[6]
y2017=dfs[7]
y2012=dfs[8]

# %%
#replace column labels
years=[y2010,y2011,y2012,y2013,y2014,y2015,y2016,y2017,y2018]
for year in years:
    year.columns=year.iloc[0]
    
y2010=y2010.drop([0])
y2011=y2011.drop([0])
y2012=y2012.drop([0])
y2013=y2013.drop([0])
y2014=y2014.drop([0])
y2015=y2015.drop([0])
y2016=y2016.drop([0])
y2017=y2017.drop([0])
y2018=y2018.drop([0])

#remove !s in column labels
y2010.columns = [x.replace('!',' ') for x in y2010.columns.values]
y2011.columns = [x.replace('!',' ') for x in y2011.columns.values]
y2012.columns = [x.replace('!',' ') for x in y2012.columns.values]
y2013.columns = [x.replace('!',' ') for x in y2013.columns.values]
y2014.columns = [x.replace('!',' ') for x in y2014.columns.values]
y2015.columns = [x.replace('!',' ') for x in y2015.columns.values]
y2016.columns = [x.replace('!',' ') for x in y2016.columns.values]
y2017.columns = [x.replace('!',' ') for x in y2017.columns.values]
y2018.columns = [x.replace('!',' ') for x in y2018.columns.values]

#drop useless columns
y2010 = y2010.drop(y2010.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2011 = y2011.drop(y2011.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2012 = y2012.drop(y2012.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2013 = y2013.drop(y2013.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2014 = y2014.drop(y2014.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2015 = y2015.drop(y2015.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2016 = y2016.drop(y2016.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2017 = y2017.drop(y2017.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2018 = y2018.drop(y2018.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)

# %%
y2013=y2013[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  Households  One race  White',
                    'Median income (dollars)  Estimate  Households  One race  Black or African American', 
                    'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  Households  One race  Asian',
                    'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  Households  One race  Some other race',
                    'Median income (dollars)  Estimate  Households  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]


y2016=y2016[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  Households  One race  White',
                    'Median income (dollars)  Estimate  Households  One race  Black or African American', 
                    'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  Households  One race  Asian',
                    'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  Households  One race  Some other race',
                    'Median income (dollars)  Estimate  Households  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2014=y2014[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  Households  One race  White',
                    'Median income (dollars)  Estimate  Households  One race  Black or African American', 
                    'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  Households  One race  Asian',
                    'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  Households  One race  Some other race',
                    'Median income (dollars)  Estimate  Households  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2011=y2011[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  One race  White',
                    'Median income (dollars)  Estimate  One race  Black or African American', 
                    'Median income (dollars)  Estimate  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  One race  Asian',
                    'Median income (dollars)  Estimate  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  One race  Some other race',
                    'Median income (dollars)  Estimate  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2010=y2010[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  One race  White',
                    'Median income (dollars)  Estimate  One race  Black or African American', 
                    'Median income (dollars)  Estimate  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  One race  Asian',
                    'Median income (dollars)  Estimate  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  One race  Some other race',
                    'Median income (dollars)  Estimate  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2015=y2015[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  Households  One race  White',
                    'Median income (dollars)  Estimate  Households  One race  Black or African American', 
                    'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  Households  One race  Asian',
                    'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  Households  One race  Some other race',
                    'Median income (dollars)  Estimate  Households  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2018=y2018[['Geographic Area Name',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  White',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Black or African American',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  American Indian and Alaska Native',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Asian',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Native Hawaiian and Other Pacific Islander',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Some other race',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  Two or more races',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  Hispanic or Latino origin (of any race)',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  White alone, not Hispanic or Latino',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2017=y2017[['Geographic Area Name',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  White',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Black or African American',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  American Indian and Alaska Native',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Asian',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Native Hawaiian and Other Pacific Islander',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Some other race',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  Two or more races',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  Hispanic or Latino origin (of any race)',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  White alone, not Hispanic or Latino',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2012=y2012[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  One race  White',
                    'Median income (dollars)  Estimate  One race  Black or African American', 
                    'Median income (dollars)  Estimate  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  One race  Asian',
                    'Median income (dollars)  Estimate  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  One race  Some other race',
                    'Median income (dollars)  Estimate  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

# %%
y2014.columns[1]
# Out:
# 'Median income (dollars)  Estimate  Households'

# %%
y2014=y2014.rename(columns={y2014.columns[1]: "Median income (dollars)  Estimate  Households",
                    y2014.columns[2]: "Median income (dollars)  Estimate  Households  One race  White", 
                    y2014.columns[3]: "Median income (dollars)  Estimate  Households  One race  Black or African American",
                    y2014.columns[4]: 'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    y2014.columns[5]: 'Median income (dollars)  Estimate  Households  One race  Asian',
                    y2014.columns[6]:'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    y2014.columns[7]:'Median income (dollars)  Estimate  Households  One race  Some other race',
                    y2014.columns[8]:'Median income (dollars)  Estimate  Households  Two or more races',
                    y2014.columns[9]:'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    y2014.columns[10]:'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    y2014.columns[11]: 'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    y2014.columns[12]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    y2014.columns[13]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    y2014.columns[14]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over'})

y2010=y2010.rename(columns={y2010.columns[1]: "Median income (dollars)  Estimate  Households",
                    y2010.columns[2]: "Median income (dollars)  Estimate  Households  One race  White", 
                    y2010.columns[3]: "Median income (dollars)  Estimate  Households  One race  Black or African American",
                    y2010.columns[4]: 'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    y2010.columns[5]: 'Median income (dollars)  Estimate  Households  One race  Asian',
                    y2010.columns[6]:'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    y2010.columns[7]:'Median income (dollars)  Estimate  Households  One race  Some other race',
                    y2010.columns[8]:'Median income (dollars)  Estimate  Households  Two or more races',
                    y2010.columns[9]:'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    y2010.columns[10]:'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    y2010.columns[11]: 'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    y2010.columns[12]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    y2010.columns[13]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    y2010.columns[14]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over'})

y2011=y2011.rename(columns={y2011.columns[1]: "Median income (dollars)  Estimate  Households",
                    y2011.columns[2]: "Median income (dollars)  Estimate  Households  One race  White", 
                    y2011.columns[3]: "Median income (dollars)  Estimate  Households  One race  Black or African American",
                    y2011.columns[4]: 'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    y2011.columns[5]: 'Median income (dollars)  Estimate  Households  One race  Asian',
                    y2011.columns[6]:'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    y2011.columns[7]:'Median income (dollars)  Estimate  Households  One race  Some other race',
                    y2011.columns[8]:'Median income (dollars)  Estimate  Households  Two or more races',
                    y2011.columns[9]:'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    y2011.columns[10]:'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    y2011.columns[11]: 'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    y2011.columns[12]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    y2011.columns[13]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    y2011.columns[14]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over'})

y2012=y2012.rename(columns={y2012.columns[1]: "Median income (dollars)  Estimate  Households",
                    y2012.columns[2]: "Median income (dollars)  Estimate  Households  One race  White", 
                    y2012.columns[3]: "Median income (dollars)  Estimate  Households  One race  Black or African American",
                    y2012.columns[4]: 'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    y2012.columns[5]: 'Median income (dollars)  Estimate  Households  One race  Asian',
                    y2012.columns[6]:'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    y2012.columns[7]:'Median income (dollars)  Estimate  Households  One race  Some other race',
                    y2012.columns[8]:'Median income (dollars)  Estimate  Households  Two or more races',
                    y2012.columns[9]:'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    y2012.columns[10]:'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    y2012.columns[11]: 'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    y2012.columns[12]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    y2012.columns[13]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    y2012.columns[14]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over'})

y2015=y2015.rename(columns={y2015.columns[1]: "Median income (dollars)  Estimate  Households",
                    y2015.columns[2]: "Median income (dollars)  Estimate  Households  One race  White", 
                    y2015.columns[3]: "Median income (dollars)  Estimate  Households  One race  Black or African American",
                    y2015.columns[4]: 'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    y2015.columns[5]: 'Median income (dollars)  Estimate  Households  One race  Asian',
                    y2015.columns[6]:'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    y2015.columns[7]:'Median income (dollars)  Estimate  Households  One race  Some other race',
                    y2015.columns[8]:'Median income (dollars)  Estimate  Households  Two or more races',
                    y2015.columns[9]:'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    y2015.columns[10]:'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    y2015.columns[11]: 'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    y2015.columns[12]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    y2015.columns[13]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    y2015.columns[14]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over'})

y2016=y2016.rename(columns={y2016.columns[1]: "Median income (dollars)  Estimate  Households",
                    y2016.columns[2]: "Median income (dollars)  Estimate  Households  One race  White", 
                    y2016.columns[3]: "Median income (dollars)  Estimate  Households  One race  Black or African American",
                    y2016.columns[4]: 'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    y2016.columns[5]: 'Median income (dollars)  Estimate  Households  One race  Asian',
                    y2016.columns[6]:'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    y2016.columns[7]:'Median income (dollars)  Estimate  Households  One race  Some other race',
                    y2016.columns[8]:'Median income (dollars)  Estimate  Households  Two or more races',
                    y2016.columns[9]:'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    y2016.columns[10]:'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    y2016.columns[11]: 'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    y2016.columns[12]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    y2016.columns[13]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    y2016.columns[14]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over'})

y2017=y2017.rename(columns={y2017.columns[1]: "Median income (dollars)  Estimate  Households",
                    y2017.columns[2]: "Median income (dollars)  Estimate  Households  One race  White", 
                    y2017.columns[3]: "Median income (dollars)  Estimate  Households  One race  Black or African American",
                    y2017.columns[4]: 'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    y2017.columns[5]: 'Median income (dollars)  Estimate  Households  One race  Asian',
                    y2017.columns[6]:'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    y2017.columns[7]:'Median income (dollars)  Estimate  Households  One race  Some other race',
                    y2017.columns[8]:'Median income (dollars)  Estimate  Households  Two or more races',
                    y2017.columns[9]:'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    y2017.columns[10]:'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    y2017.columns[11]: 'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    y2017.columns[12]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    y2017.columns[13]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    y2017.columns[14]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over'})

y2018=y2018.rename(columns={y2018.columns[1]: "Median income (dollars)  Estimate  Households",
                    y2018.columns[2]: "Median income (dollars)  Estimate  Households  One race  White", 
                    y2018.columns[3]: "Median income (dollars)  Estimate  Households  One race  Black or African American",
                    y2018.columns[4]: 'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    y2018.columns[5]: 'Median income (dollars)  Estimate  Households  One race  Asian',
                    y2018.columns[6]:'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    y2018.columns[7]:'Median income (dollars)  Estimate  Households  One race  Some other race',
                    y2018.columns[8]:'Median income (dollars)  Estimate  Households  Two or more races',
                    y2018.columns[9]:'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    y2018.columns[10]:'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    y2018.columns[11]: 'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    y2018.columns[12]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    y2018.columns[13]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    y2018.columns[14]:'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over'})

# %%
y2010['Year']=2010
y2011['Year']=2011
y2012['Year']=2012
y2013['Year']=2013
y2014['Year']=2014
y2015['Year']=2015
y2016['Year']=2016
y2017['Year']=2017
y2018['Year']=2018

# %%
df=pd.concat([y2013,y2014,y2010,y2011,y2012,y2015,y2016,y2017,y2018])

# %%
sf=pd.read_csv('sf polygons.csv')

# %%
polys = [shapely.wkt.loads(st) for st in sf['geometry']]

# %%
tracts=[]

for d in df['Geographic Area Name']:
    if re.findall(r'(\d\d\d.\d\d|\d\d\d|\d\d\d\d)',d):
        tracts.append(str(re.findall(r'(\d\d\d\d|\d\d\d.\d\d|\d\d\d)',d)[0]))
    else:
        tracts.append(str(''))
    
df['tract']=tracts
df['tract']=df['tract'].astype(str)

# %%
sf['NAME']=sf['NAME'].astype(str)

# %%
df1=df.merge(sf[['NAME','geometry']],left_on='tract',right_on='NAME')
df1=df1.drop(['NAME'],axis=1)

# %%
# y2010.to_csv('2010_med_income.csv')
# y2011.to_csv('2011_med_income.csv')
# y2012.to_csv('2012_med_income.csv')
# y2013.to_csv('2013_med_income.csv')
# y2014.to_csv('2014_med_income.csv')
# y2015.to_csv('2015_med_income.csv')
# y2016.to_csv('2016_med_income.csv')
# y2017.to_csv('2017_med_income.csv')
y2018.to_csv('2018_med_income.csv')

# %%
df1.to_csv('med_income.csv')

# %%
y2018['Geographic Area Name']
# Out:
# 0      Census Tract 101, San Francisco County, Califo...
# 1      Census Tract 102, San Francisco County, Califo...
# 2      Census Tract 103, San Francisco County, Califo...
# 3      Census Tract 104, San Francisco County, Califo...
# 4      Census Tract 105, San Francisco County, Califo...
# 5      Census Tract 106, San Francisco County, Califo...
# 6      Census Tract 107, San Francisco County, Califo...
# 7      Census Tract 108, San Francisco County, Califo...
# 8      Census Tract 109, San Francisco County, Califo...
# 9      Census Tract 110, San Francisco County, Califo...
# 10     Census Tract 111, San Francisco County, Califo...
# 11     Census Tract 112, San Francisco County, Califo...
# 12     Census Tract 113, San Francisco County, Califo...
# 13     Census Tract 117, San Francisco County, Califo...
# 14     Census Tract 118, San Francisco County, Califo...
# 15     Census Tract 119.01, San Francisco County, Cal...
# 16     Census Tract 119.02, San Francisco County, Cal...
# 17     Census Tract 120, San Francisco County, Califo...
# 18     Census Tract 121, San Francisco County, Califo...
# 19     Census Tract 122.01, San Francisco County, Cal...
# 20     Census Tract 122.02, San Francisco County, Cal...
# 21     Census Tract 123.01, San Francisco County, Cal...
# 22     Census Tract 123.02, San Francisco County, Cal...
# 23     Census Tract 124.01, San Francisco County, Cal...
# 24     Census Tract 124.02, San Francisco County, Cal...
# 25     Census Tract 125.01, San Francisco County, Cal...
# 26     Census Tract 125.02, San Francisco County, Cal...
# 27     Census Tract 126.01, San Francisco County, Cal...
# 28     Census Tract 126.02, San Francisco County, Cal...
# 29     Census Tract 127, San Francisco County, Califo...
#                              ...
# 169    Census Tract 426.02, San Francisco County, Cal...
# 170    Census Tract 427, San Francisco County, Califo...
# 171    Census Tract 428, San Francisco County, Califo...
# 172    Census Tract 451, San Francisco County, Califo...
# 173    Census Tract 452, San Francisco County, Califo...
# 174    Census Tract 476, San Francisco County, Califo...
# 175    Census Tract 477.01, San Francisco County, Cal...
# 176    Census Tract 477.02, San Francisco County, Cal...
# 177    Census Tract 478.01, San Francisco County, Cal...
# 178    Census Tract 478.02, San Francisco County, Cal...
# 179    Census Tract 479.01, San Francisco County, Cal...
# 180    Census Tract 479.02, San Francisco County, Cal...
# 181    Census Tract 601, San Francisco County, Califo...
# 182    Census Tract 604, San Francisco County, Califo...
# 183    Census Tract 605.02, San Francisco County, Cal...
# 184    Census Tract 607, San Francisco County, Califo...
# 185    Census Tract 610, San Francisco County, Califo...
# 186    Census Tract 611, San Francisco County, Califo...
# 187    Census Tract 612, San Francisco County, Califo...
# 188    Census Tract 614, San Francisco County, Califo...
# 189    Census Tract 615, San Francisco County, Califo...
# 190    Census Tract 9802, San Francisco County, Calif...
# 191    Census Tract 9803, San Francisco County, Calif...
# 192    Census Tract 9804.01, San Francisco County, Ca...
# 193    Census Tract 9805.01, San Francisco County, Ca...
# 194    Census Tract 9806, San Francisco County, Calif...
# 195    Census Tract 9809, San Francisco County, Calif...
# 196    Census Tract 9901, San Francisco County, Calif...
# 197                                        United States
# 198                       San Francisco city, California
# Name: Geographic Area Name, Length: 199, dtype: object
