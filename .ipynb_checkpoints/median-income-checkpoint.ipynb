# %%
import glob
import pandas as pd

# %%
path = '/Users/renasong/Documents/2020su/proj/income'
all_files = glob.glob(path + "/*.csv")
li = []

for filename in all_files:
    df = pd.read_csv(filename)
    li.append(df)

raw = pd.concat(li, axis=0, ignore_index=True)
# Out:
# /Users/renasong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':

# %%
dfs=[pd.DataFrame(x) for x in li]

# %%
y2013=dfs[0]
y2016=dfs[1]
y2014=dfs[2]
y2011=dfs[3]
y2010=dfs[4]
y2015=dfs[5]
y2018=dfs[6]
y2017=dfs[7]
y2012=dfs[8]

# %%
#replace column labels
years=[y2010,y2011,y2012,y2013,y2014,y2015,y2016,y2017,y2018]
for year in years:
    year.columns=year.iloc[0]
    
y2010=y2010.drop([0])
y2011=y2011.drop([0])
y2012=y2012.drop([0])
y2013=y2013.drop([0])
y2014=y2014.drop([0])
y2015=y2015.drop([0])
y2016=y2016.drop([0])
y2017=y2017.drop([0])
y2018=y2018.drop([0])

#remove !s in column labels
y2010.columns = [x.replace('!',' ') for x in y2010.columns.values]
y2011.columns = [x.replace('!',' ') for x in y2011.columns.values]
y2012.columns = [x.replace('!',' ') for x in y2012.columns.values]
y2013.columns = [x.replace('!',' ') for x in y2013.columns.values]
y2014.columns = [x.replace('!',' ') for x in y2014.columns.values]
y2015.columns = [x.replace('!',' ') for x in y2015.columns.values]
y2016.columns = [x.replace('!',' ') for x in y2016.columns.values]
y2017.columns = [x.replace('!',' ') for x in y2017.columns.values]
y2018.columns = [x.replace('!',' ') for x in y2018.columns.values]

#drop useless columns
y2010 = y2010.drop(y2010.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2011 = y2011.drop(y2011.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2012 = y2012.drop(y2012.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2013 = y2013.drop(y2013.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2014 = y2014.drop(y2014.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2015 = y2015.drop(y2015.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2016 = y2016.drop(y2016.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2017 = y2017.drop(y2017.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)
y2018 = y2018.drop(y2018.columns[-6:],axis=1).drop(['id'],axis=1).reset_index().drop(['index'],axis=1)

# %%
y2013=y2013[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  Households  One race  White',
                    'Median income (dollars)  Estimate  Households  One race  Black or African American', 
                    'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  Households  One race  Asian',
                    'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  Households  One race  Some other race',
                    'Median income (dollars)  Estimate  Households  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2016=y2016[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  Households  One race  White',
                    'Median income (dollars)  Estimate  Households  One race  Black or African American', 
                    'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  Households  One race  Asian',
                    'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  Households  One race  Some other race',
                    'Median income (dollars)  Estimate  Households  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2014=y2014[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  Households  One race  White',
                    'Median income (dollars)  Estimate  Households  One race  Black or African American', 
                    'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  Households  One race  Asian',
                    'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  Households  One race  Some other race',
                    'Median income (dollars)  Estimate  Households  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2011=y2011[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  One race  White',
                    'Median income (dollars)  Estimate  One race  Black or African American', 
                    'Median income (dollars)  Estimate  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  One race  Asian',
                    'Median income (dollars)  Estimate  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  One race  Some other race',
                    'Median income (dollars)  Estimate  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2010=y2010[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  One race  White',
                    'Median income (dollars)  Estimate  One race  Black or African American', 
                    'Median income (dollars)  Estimate  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  One race  Asian',
                    'Median income (dollars)  Estimate  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  One race  Some other race',
                    'Median income (dollars)  Estimate  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2015=y2015[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  Households  One race  White',
                    'Median income (dollars)  Estimate  Households  One race  Black or African American', 
                    'Median income (dollars)  Estimate  Households  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  Households  One race  Asian',
                    'Median income (dollars)  Estimate  Households  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  Households  One race  Some other race',
                    'Median income (dollars)  Estimate  Households  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2018=y2018[['Geographic Area Name',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  White',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Black or African American',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  American Indian and Alaska Native',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Asian',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Native Hawaiian and Other Pacific Islander',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Some other race',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  Two or more races',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  Hispanic or Latino origin (of any race)',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  White alone, not Hispanic or Latino',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2017=y2017[['Geographic Area Name',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  White',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Black or African American',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  American Indian and Alaska Native',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Asian',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Native Hawaiian and Other Pacific Islander',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  One race--  Some other race',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  Two or more races',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  Hispanic or Latino origin (of any race)',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY RACE AND HISPANIC OR LATINO ORIGIN OF HOUSEHOLDER  Households  White alone, not Hispanic or Latino',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
             'Estimate  Median income (dollars)  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]

y2012=y2012[['Geographic Area Name',
             'Median income (dollars)  Estimate  Households',
                    'Median income (dollars)  Estimate  One race  White',
                    'Median income (dollars)  Estimate  One race  Black or African American', 
                    'Median income (dollars)  Estimate  One race  American Indian and Alaska Native',
                    'Median income (dollars)  Estimate  One race  Asian',
                    'Median income (dollars)  Estimate  One race  Native Hawaiian and Other Pacific Islander',
                    'Median income (dollars)  Estimate  One race  Some other race',
                    'Median income (dollars)  Estimate  Two or more races',
                    'Median income (dollars)  Estimate  Hispanic or Latino origin (of any race)',
                    'Median income (dollars)  Estimate  White alone, not Hispanic or Latino',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  15 to 24 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  25 to 44 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  45 to 64 years',
                    'Median income (dollars)  Estimate  HOUSEHOLD INCOME BY AGE OF HOUSEHOLDER  65 years and over']]
